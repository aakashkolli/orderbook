# %% [markdown]
# # PnL Analysis
#
# Analyze fill simulator and PnL tracker output from the ITCH 5.0 replay engine.
#
# ## Setup
#
# Run the replay binary with JSON output first:
# ```bash
# ./build/replay data/mock.NASDAQ_ITCH50 --checksum
# ```

# %%
import subprocess
import numpy as np

# Placeholder: extend with actual fill data export from replay binary.
print('PnL analysis notebook — wire in fill data from replay binary output.')
